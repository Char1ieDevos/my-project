# %% [markdown]
# <a href="https://colab.research.google.com/github/Char1ieDevos/my-project/blob/main/Pandas_Documentation_Expo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

s = pd.Series([1, 3, 5, np.nan, 6, 8])

dates = pd.date_range("20130101", periods=6)

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))

# %%
In [17]: df.to_numpy()
# Out:
# array([[-1.38898312e+00,  9.64125372e-01,  5.17748505e-01,
#         -5.91184929e-01],
#        [ 3.55403066e-01,  9.21875097e-03, -6.99256418e-01,
#          1.95291442e-01],
#        [-1.46926623e+00, -1.48377862e+00, -7.68794990e-01,
#         -1.06785524e+00],
#        [-9.04506470e-01, -1.14143488e-03,  3.49291372e-01,
#         -1.77772892e+00],
#        [-8.59916849e-01, -7.24380691e-02, -5.38458516e-01,
#         -1.88664850e+00],
#        [ 1.16946699e+00,  2.55911461e-01, -1.75811004e+00,
#         -7.76918687e-01]])

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01 -0.591185  0.517749  0.964125 -1.388983
# 2013-01-02  0.195291 -0.699256  0.009219  0.355403
# 2013-01-03 -1.067855 -0.768795 -1.483779 -1.469266
# 2013-01-04 -1.777729  0.349291 -0.001141 -0.904506
# 2013-01-05 -1.886648 -0.538459 -0.072438 -0.859917
# 2013-01-06 -0.776919 -1.758110  0.255911  1.169467

# %%
df.sort_values(by="B")
# Out:
#                    A         B         C         D
# 2013-01-03 -1.469266 -1.483779 -0.768795 -1.067855
# 2013-01-05 -0.859917 -0.072438 -0.538459 -1.886648
# 2013-01-04 -0.904506 -0.001141  0.349291 -1.777729
# 2013-01-02  0.355403  0.009219 -0.699256  0.195291
# 2013-01-06  1.169467  0.255911 -1.758110 -0.776919
# 2013-01-01 -1.388983  0.964125  0.517749 -0.591185

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04 -0.904506 -0.001141
# 2013-01-05 -0.859917 -0.072438

# %%
df.iloc[3]
# Out:
# A   -0.904506
# B   -0.001141
# C    0.349291
# D   -1.777729
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2013-01-02  0.355403  0.009219 -0.699256  0.195291
# 2013-01-03 -1.469266 -1.483779 -0.768795 -1.067855

# %%
df.iat[1, 1]
# Out:
# np.float64(0.009218750973995821)

# %%
df2 = df.copy()

df2["E"] = ["one", "one", "two", "three", "four", "three"]

df2
# Out:
#                    A         B         C         D      E
# 2013-01-01 -1.388983  0.964125  0.517749 -0.591185    one
# 2013-01-02  0.355403  0.009219 -0.699256  0.195291    one
# 2013-01-03 -1.469266 -1.483779 -0.768795 -1.067855    two
# 2013-01-04 -0.904506 -0.001141  0.349291 -1.777729  three
# 2013-01-05 -0.859917 -0.072438 -0.538459 -1.886648   four
# 2013-01-06  1.169467  0.255911 -1.758110 -0.776919  three

# %%
df2[df2["E"].isin(["two", "four"])]
# Out:
#                    A         B         C         D     E
# 2013-01-03 -1.469266 -1.483779 -0.768795 -1.067855   two
# 2013-01-05 -0.859917 -0.072438 -0.538459 -1.886648  four

# %%
s1 = pd.Series(
   [1, 2, 3, 4, 5, 6],
   index=pd.date_range("20130102", periods=6))

# %%
df.iat[1, 1]
# Out:
# np.float64(0.009218750973995821)

# %%
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2013-01-02  0.355403  0.009219 -0.699256  0.195291
# 2013-01-06  1.169467  0.255911 -1.758110 -0.776919

# %%
df.at[dates[0], "A"] = 0

# %%
df.loc[:, "D"] = np.array([5] * len(df))

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["E"])

df1.loc[dates[0] : dates[1], "E"] = 1

df1
# Out:
#                    A         B         C    D    E
# 2013-01-01  0.000000  0.964125  0.517749  5.0  1.0
# 2013-01-02  0.355403  0.009219 -0.699256  5.0  1.0
# 2013-01-03 -1.469266 -1.483779 -0.768795  5.0  NaN
# 2013-01-04 -0.904506 -0.001141  0.349291  5.0  NaN

# %%
df1.dropna(how="any")
# Out:
#                    A         B         C    D    E
# 2013-01-01  0.000000  0.964125  0.517749  5.0  1.0
# 2013-01-02  0.355403  0.009219 -0.699256  5.0  1.0

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C    D    E
# 2013-01-01  0.000000  0.964125  0.517749  5.0  1.0
# 2013-01-02  0.355403  0.009219 -0.699256  5.0  1.0
# 2013-01-03 -1.469266 -1.483779 -0.768795  5.0  5.0
# 2013-01-04 -0.904506 -0.001141  0.349291  5.0  5.0

# %%
df.agg(lambda x: np.mean(x) * 5.6)
# Out:
# A    -1.594898
# B    -0.306229
# C    -2.704408
# D    28.000000
# dtype: float64

# %%
pieces = [df[:3], df[3:7], df[7:]]

df.transform(lambda x: x * 101.2)
# Out:
#                      A           B           C      D
# 2013-01-01    0.000000   97.569488   52.396149  506.0
# 2013-01-02   35.966790    0.932938  -70.764749  506.0
# 2013-01-03 -148.689743 -150.158396  -77.802053  506.0
# 2013-01-04  -91.536055   -0.115513   35.348287  506.0
# 2013-01-05  -87.023585   -7.330733  -54.492002  506.0
# 2013-01-06  118.350060   25.898240 -177.920736  506.0

# %%
pd.concat(pieces)
# Out:
#                    A         B         C    D
# 2013-01-01  0.000000  0.964125  0.517749  5.0
# 2013-01-02  0.355403  0.009219 -0.699256  5.0
# 2013-01-03 -1.469266 -1.483779 -0.768795  5.0
# 2013-01-04 -0.904506 -0.001141  0.349291  5.0
# 2013-01-05 -0.859917 -0.072438 -0.538459  5.0
# 2013-01-06  1.169467  0.255911 -1.758110  5.0

# %%
left = pd.DataFrame({"key": ["foo", "foo"], "lval": [1, 2]})

right = pd.DataFrame({"key": ["foo", "foo"], "rval": [4, 5]})

# %%
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
df = pd.DataFrame(
    {
        "A": ["foo", "bar", "foo", "bar", "foo", "bar", "foo", "foo"],
        "B": ["one", "one", "two", "three", "two", "two", "one", "three"],
        "C": np.random.randn(8),
        "D": np.random.randn(8),
    }
)

# %%
df.groupby("A")[["C", "D"]].sum()
# Out:
#             C         D
# A
# bar -0.910144 -2.344629
# foo  0.885880 -3.426565

# %%
df.groupby(["A", "B"]).sum()
# Out:
#                   C         D
# A   B
# bar one   -1.454894 -1.647352
#     three  0.446529 -1.352351
#     two    0.098222  0.655074
# foo one    0.550892 -2.785467
#     three  0.547504 -0.931028
#     two   -0.212515  0.289931

# %%
index = pd.MultiIndex.from_arrays(arrays, names=["first", "second"])

df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=["A", "B"])

df2 = df[:4]

df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2125891887.py in <cell line: 0>()
# ----> 1 index = pd.MultiIndex.from_arrays(arrays, names=["first", "second"])
#       2
#       3 df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=["A", "B"])
#       4
#       5 df2 = df[:4]
#
# NameError: name 'arrays' is not defined

# %%
stacked = df2.stack()

stacked

# %%
stacked.unstack()

# %%
df = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
    }
)

pd.pivot_table(df, values="D", index=["A", "B"], columns=["C"])

# %%
rng = pd.date_range("1/1/2012", periods=100, freq="s")

ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

ts.resample("5Min").sum()

# %%
import matplotlib.pyplot as plt

plt.close("all")

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))

ts = ts.cumsum()

ts.plot();

# %%
df = pd.DataFrame(np.random.randint(0, 5, (10, 5)))

df.to_csv("foo.csv")

# %%
df.to_parquet("foo.parquet")

# %%
df.to_excel("foo.xlsx", sheet_name="Sheet1")

# %%
df = pd.DataFrame(np.random.randint(0, 5, (10, 5)))

df.to_csv("foo.csv")

# %%
df = pd.DataFrame(np.random.randint(0, 5, (10, 5)))

df.to_csv("foo.csv")

# %%
ts_utc = ts.tz_localize("UTC")
rng = pd.date_range("3/6/2012 00:00", periods=5, freq="D")

ts = pd.Series(np.random.randn(len(rng)), rng)

ts

ts_utc.tz_convert("US/Eastern")
# Out:
# 1999-12-31 19:00:00-05:00     1.168149
# 2000-01-01 19:00:00-05:00     0.646448
# 2000-01-02 19:00:00-05:00     2.527299
# 2000-01-03 19:00:00-05:00     3.859698
# 2000-01-04 19:00:00-05:00     3.012132
#                                ...
# 2002-09-21 20:00:00-04:00   -38.010961
# 2002-09-22 20:00:00-04:00   -36.773741
# 2002-09-23 20:00:00-04:00   -37.520217
# 2002-09-24 20:00:00-04:00   -36.910238
# 2002-09-25 20:00:00-04:00   -37.005651
# Freq: D, Length: 1000, dtype: float64
